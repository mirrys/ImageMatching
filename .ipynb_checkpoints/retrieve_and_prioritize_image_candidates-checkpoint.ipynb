# %%
import pyspark
import re
import pyspark.sql
import pickle
import pandas as pd
import math
import numpy as np
import random
import requests
#from bs4 import BeautifulSoup
import json

# %%
# !which python
# Out:
# /home/mirrys/venv/bin/python

# %%
qids_and_properties={}

# %%
languages=['enwiki','arwiki','kowiki','cswiki','viwiki','frwiki','fawiki','ptwiki','ruwiki','trwiki','plwiki','hewiki','svwiki','ukwiki','huwiki','hywiki','srwiki','euwiki','arzwiki','cebwiki','dewiki','bnwiki'] #language editions to consider
#val=100 #threshold above which we consider images as non-icons
#languages=['itwiki']

# %%
len(languages)
# Out:
# 22

# %%
def get_threshold(wiki_size):
    #change th to optimize precision vs recall. recommended val for accuracy = 5
    sze, th, lim = 50000, 15, 4 
    if (wiki_size >= sze):
        #if wiki_size > base size, scale threshold by (log of ws/bs) + 1
        return (math.log(wiki_size/sze, 10)+1)*th
    #else scale th down by ratio bs/ws, w min possible val of th = th/limiting val
    return max((wiki_size/sze) * th, th/lim)

# %%
val={}
total={}
for wiki in languages:
     querytot="""SELECT COUNT(*) as c
     FROM wmf_raw.mediawiki_page
     WHERE page_namespace=0 
     AND page_is_redirect=0
     AND snapshot='2020-11' 
     AND wiki_db='"""+wiki+"""'"""
     wikisize = spark.sql(querytot).toPandas()
     val[wiki]=get_threshold(int(wikisize['c']))
     total[wiki]=int(wikisize['c'])

# %% [markdown]
# The query below retrieves, for each unillustrated article: its Wikidata ID, the image of the Wikidata ID (if any), the Commons category of the Wikidata ID (if any), and the lead images of the articles in other languages (if any).
#
# `allowed_images` contains the list of icons (images appearing in more than `val` articles)
#
# `image_pageids` contains the list of illustrated articles (articles with images that are not icons)
#
# `noimage_pages` contains the pageid and Qid of unillustrated articles
#
# `qid_props` contains for each Qid in `noimage_pages`, the values of the following properties, when present:
# * P18: the item's image
# * P373: the item's Commons category
# * P31: the item's "instance of" property
#
# `category_image_list` contains the list of all images in a
#
# `lan_page_images` contains the list of lead images in Wikipedia articles in all languages linked to each Qid
#
# `qid_props_with_image_list` is qid_props plus the list of images in the Commons category linked to the Wikidata item

# %%
for wiki in languages:
     print(wiki)
     queryd="""WITH allowed_images AS 
     (
     SELECT il_to
     FROM wmf_raw.mediawiki_imagelinks
     WHERE il_from_namespace=0 
     AND snapshot='2020-11'  
     AND wiki_db='"""+wiki+"""' 
     AND il_to not like '%\"%' AND il_to not like '%,%'
     GROUP BY il_to  
     HAVING COUNT(il_to)>"""+str(val[wiki])+"""),
     image_pageids AS 
     (SELECT DISTINCT il_from as pageid
     FROM wmf_raw.mediawiki_imagelinks il1 
     LEFT ANTI JOIN allowed_images
     ON allowed_images.il_to=il1.il_to
     WHERE il1.il_from_namespace=0 
     AND il1.wiki_db='"""+wiki+"""' 
     AND il1.snapshot='2020-11'
     ),
     pageimage_pageids AS 
     (
     SELECT DISTINCT pp_page as pageid
     FROM wmf_raw.mediawiki_page_props pp
     WHERE pp.wiki_db ='"""+wiki+"""'
     AND pp.snapshot='2020-11'
     AND pp_propname in ('page_image','page_image_free')),
     all_image_pageids as(
     SELECT pageid 
     FROM image_pageids 
     UNION
     SELECT pageid
     FROM pageimage_pageids
     ),
     noimage_pages as 
     (
     SELECT wipl.item_id,p.page_id,p.page_title,page_len
     FROM wmf_raw.mediawiki_page p 
     JOIN wmf.wikidata_item_page_link wipl
     ON p.page_id=wipl.page_id
     LEFT ANTI JOIN all_image_pageids
     on all_image_pageids.pageid=wipl.page_id
     WHERE p.page_namespace=0 
     AND page_is_redirect=0 AND p.wiki_db='"""+wiki+"""' 
     AND p.snapshot='2020-11' 
     AND wipl.snapshot='2020-11-30'
     AND wipl.page_namespace=0
     AND wipl.wiki_db='"""+wiki+"""'
     ORDER BY page_len desc
     ),
     qid_props AS 
     (
     SELECT we.id,label_val, 
     MAX(CASE WHEN claim.mainSnak.property = 'P18' THEN claim.mainSnak.datavalue.value ELSE NULL END) AS hasimage,
     MAX(CASE WHEN claim.mainSnak.property = 'P373' THEN REPLACE(REPLACE(claim.mainSnak.datavalue.value,'\"',''),' ','_') ELSE NULL END) AS commonscategory,
     MAX(CASE WHEN claim.mainSnak.property = 'P31' THEN claim.mainSnak.datavalue.value ELSE NULL END) AS instanceof
     FROM wmf.wikidata_entity we
     JOIN noimage_pages
     ON we.id=noimage_pages.item_id
     LATERAL VIEW explode(labels) t AS label_lang,label_val
     LATERAL VIEW OUTER explode(claims) c AS claim
     WHERE t.label_lang='en'
     AND typ='item'
     AND snapshot='2020-11-30'
     AND claim.mainSnak.property in ('P18','P31','P373')
     GROUP BY id,label_val
     ),
     category_image_list AS
     (
     SELECT cl_to,concat_ws(';',collect_list(mp.page_title)) as category_imagelist
     from qid_props
     left join wmf_raw.mediawiki_categorylinks mc
     on qid_props.commonscategory=mc.cl_to
     join wmf_raw.mediawiki_page mp
     on mp.page_id=mc.cl_from
     WHERE mp.wiki_db ='commonswiki'
     AND mp.snapshot='2020-11'
     AND mp.page_namespace=6
     AND mp.page_is_redirect=0
     AND mc.snapshot='2020-11'
     AND mc.wiki_db ='commonswiki'
     AND mc.cl_type='file'
     group by mc.cl_to
     ),
     qid_props_with_image_list AS
     (
     SELECT id, label_val, hasimage, commonscategory, instanceof,category_imagelist
     from qid_props
     left join category_image_list
     on qid_props.commonscategory=category_image_list.cl_to
     ),
     lan_page_images AS
     (
     SELECT nip.item_id,nip.page_id,nip.page_title,nip.page_len,collect_list(concat(pp.wiki_db,': ',pp.pp_value)) as lan_images
     FROM noimage_pages nip
     LEFT JOIN  wmf.wikidata_item_page_link wipl
     LEFT JOIN wmf_raw.mediawiki_page_props pp
     LEFT JOIN wmf_raw.mediawiki_page mp
     ON nip.item_id=wipl.item_id
     AND wipl.page_id=pp.pp_page
     AND wipl.wiki_db=pp.wiki_db
     AND mp.page_title=pp.pp_value
     WHERE wipl.wiki_db !='"""+wiki+"""'
     AND wipl.snapshot='2020-11-30'
     AND wipl.page_namespace=0
     AND pp.snapshot='2020-11'
     AND pp_propname in ('page_image','page_image_free')
     AND mp.wiki_db ='commonswiki'
     AND mp.snapshot='2020-11'
     AND mp.page_namespace=6
     AND mp.page_is_redirect=0
     GROUP BY nip.item_id,nip.page_id,nip.page_title,nip.page_len
     ),
     joined_lan_page_images AS
     (
     SELECT nip.item_id,nip.page_id,nip.page_title,nip.page_len, lpi.lan_images
     from noimage_pages nip
     LEFT JOIN lan_page_images lpi
     on nip.item_id=lpi.item_id
     )
     SELECT * from joined_lan_page_images
     LEFT JOIN qid_props_with_image_list
     on qid_props_with_image_list.id=joined_lan_page_images.item_id
     
     """
     qid_props = spark.sql(queryd).toPandas()
     qids_and_properties[wiki]=qid_props
# Out:
# enwiki
# arwiki
# kowiki
# cswiki
# viwiki
# frwiki
# fawiki
# ptwiki
# ruwiki
# trwiki
# plwiki
# hewiki
# svwiki
# ukwiki
# huwiki
# hywiki
# srwiki
# euwiki
# arzwiki
# cebwiki
# dewiki
# bnwiki

# %% [markdown]
# Below I am just creating different tables according to whether an image is retrieved from a specific source (Wikidata image, Commons Category, or interlingual links)

# %%
hasimage={}
commonscategory={}
lanimages={}
allimages={}
for wiki in languages:
    print(wiki)
    hasimage[wiki]=qids_and_properties[wiki][qids_and_properties[wiki]['hasimage'].astype(str).ne('None')]
    commonscategory[wiki]=qids_and_properties[wiki][qids_and_properties[wiki]['category_imagelist'].astype(str).ne('None')]
    lanimages[wiki]=qids_and_properties[wiki][qids_and_properties[wiki]['lan_images'].astype(str).ne('None')]
    print("number of unillustrated articles: "+str(len(qids_and_properties[wiki])))
    print("number of articles items with Wikidata image: "+str(len(hasimage[wiki])))
    print("number of articles items with Wikidata Commons Category: "+str(len(commonscategory[wiki])))
    print("number of articles items with Language Links: "+str(len(lanimages[wiki])))
    ####
    allimages[wiki]=qids_and_properties[wiki][(qids_and_properties[wiki]['hasimage'].astype(str).ne('None')) | (qids_and_properties[wiki]['lan_images'].astype(str).ne('None')) | (qids_and_properties[wiki]['category_imagelist'].astype(str).ne('None'))]
    #allimages[wiki].to_csv('Output/'wiki+'_wd_images.tsv',sep='\t')
#     commonscategory[wiki]=commonscategory[wiki].set_index('item_id')
#     hasimage[wiki]=hasimage[wiki].set_index('item_id')
#     lanimages[wiki]=lanimages[wiki].set_index('item_id')
#     allimages[wiki]=qids_and_properties[wiki][(qids_and_properties[wiki]['hasimage'].astype(str).ne('None')) | (qids_and_properties[wiki]['commonscategory'].astype(str).ne('None')) | (qids_and_properties[wiki]['lan_images'].astype(str).ne('None'))]
#     allimages[wiki].to_csv(wiki+'_wd_images.tsv',sep='\t')
# Out:
# enwiki
# number of unillustrated articles: 2932613
# number of articles items with Wikidata image: 36630
# number of articles items with Wikidata Commons Category: 55628
# number of articles items with Language Links: 270047
# arwiki
# number of unillustrated articles: 581710
# number of articles items with Wikidata image: 7075
# number of articles items with Wikidata Commons Category: 22343
# number of articles items with Language Links: 94872
# kowiki
# number of unillustrated articles: 274338
# number of articles items with Wikidata image: 16106
# number of articles items with Wikidata Commons Category: 23922
# number of articles items with Language Links: 60954
# cswiki
# number of unillustrated articles: 182177
# number of articles items with Wikidata image: 8359
# number of articles items with Wikidata Commons Category: 16394
# number of articles items with Language Links: 52245
# viwiki
# number of unillustrated articles: 867672
# number of articles items with Wikidata image: 49246
# number of articles items with Wikidata Commons Category: 47527
# number of articles items with Language Links: 111080
# frwiki
# number of unillustrated articles: 952994
# number of articles items with Wikidata image: 10975
# number of articles items with Wikidata Commons Category: 29480
# number of articles items with Language Links: 134307
# fawiki
# number of unillustrated articles: 304253
# number of articles items with Wikidata image: 23729
# number of articles items with Wikidata Commons Category: 25880
# number of articles items with Language Links: 119787
# ptwiki
# number of unillustrated articles: 388605
# number of articles items with Wikidata image: 29809
# number of articles items with Wikidata Commons Category: 33476
# number of articles items with Language Links: 102324
# ruwiki
# number of unillustrated articles: 584290
# number of articles items with Wikidata image: 5465
# number of articles items with Wikidata Commons Category: 19191
# number of articles items with Language Links: 88680
# trwiki
# number of unillustrated articles: 151620
# number of articles items with Wikidata image: 12446
# number of articles items with Wikidata Commons Category: 17020
# number of articles items with Language Links: 49461
# plwiki
# number of unillustrated articles: 560334
# number of articles items with Wikidata image: 13918
# number of articles items with Wikidata Commons Category: 25283
# number of articles items with Language Links: 100091
# hewiki
# number of unillustrated articles: 73261
# number of articles items with Wikidata image: 2377
# number of articles items with Wikidata Commons Category: 6752
# number of articles items with Language Links: 19994
# svwiki
# number of unillustrated articles: 1686664
# number of articles items with Wikidata image: 28791
# number of articles items with Wikidata Commons Category: 39101
# number of articles items with Language Links: 127625
# ukwiki
# number of unillustrated articles: 365209
# number of articles items with Wikidata image: 11669
# number of articles items with Wikidata Commons Category: 18441
# number of articles items with Language Links: 80714
# huwiki
# number of unillustrated articles: 170936
# number of articles items with Wikidata image: 3918
# number of articles items with Wikidata Commons Category: 12441
# number of articles items with Language Links: 36631
# hywiki
# number of unillustrated articles: 96729
# number of articles items with Wikidata image: 2311
# number of articles items with Wikidata Commons Category: 6710
# number of articles items with Language Links: 23753
# srwiki
# number of unillustrated articles: 126102
# number of articles items with Wikidata image: 9852
# number of articles items with Wikidata Commons Category: 11113
# number of articles items with Language Links: 39362
# euwiki
# number of unillustrated articles: 105412
# number of articles items with Wikidata image: 2207
# number of articles items with Wikidata Commons Category: 8930
# number of articles items with Language Links: 33355
# arzwiki
# number of unillustrated articles: 759418
# number of articles items with Wikidata image: 1078
# number of articles items with Wikidata Commons Category: 12198
# number of articles items with Language Links: 149212
# cebwiki
# number of unillustrated articles: 1357405
# number of articles items with Wikidata image: 34900
# number of articles items with Wikidata Commons Category: 47452
# number of articles items with Language Links: 105069
# dewiki
# number of unillustrated articles: 1190517
# number of articles items with Wikidata image: 38367
# number of articles items with Wikidata Commons Category: 40179
# number of articles items with Language Links: 156117
# bnwiki
# number of unillustrated articles: 33642
# number of articles items with Wikidata image: 2325
# number of articles items with Wikidata Commons Category: 4795
# number of articles items with Language Links: 10187

# %% [markdown]
# Below the two functions to select images depending on the source:
# * `select_image_language` takes as input the list of images from articles in multiple languages and selects the one which is used more often across languages (after some major filtering)
# * `select_image_category` selects at random one of the images in the Commons category linked to the Wikidata item.

# %%
def image_language_checks(iname):
    #list of substrings to check for
    substring_list=['.svg','flag','noantimage','no_free_image','image_manquante',
                    'replace_this_image','disambig','regions','map','map','default',
                    'defaut','falta_imagem_','imageNA','noimage','noenzyimage']
    iname=iname.lower()
    if any(map(iname.__contains__, substring_list)):
        return False
    else:
        return True

def select_image_language(imagelist): 
    counts={} #contains counts of image occurrences across languages
    languages={} #constains which languages cover a given image
    #for each image
    for image in imagelist:
        data=image.strip().split(' ')#this contains the language and image name data
        ###
        if len(data)==2: #if we actually have 2 fields
            iname=data[1].strip()
            ###
            if iname not in counts: #if this image does not exist in our counts yet, initialize counts
                if not image_language_checks(iname): #if the image name is not valid
                    continue
               # urll = 'https://commons.wikimedia.org/wiki/File:'+iname.replace(' ','_')+'?uselang='+language
                #page = requests.get(urll)
                #if page.status_code == 404:
                 #   print (urll)
                 #   continue
                lan=data[0].strip()[1:-1]
                counts[iname]=1
                languages[iname]=[]
            else:
                counts[iname]+=1
            languages[iname].append(lan)
    ###
    if len(counts)==0:#if we don't have image candidates
        val=None
        lans=None
        counts={}
    else:#otherwise pick the image which has been used more often across languages
        index=np.argmax(list(counts.values()))
        val=list(counts.keys())[index]
        lans=languages[val]
    return val,lans,list(counts.keys())

def select_image_category(imagelist):
    counts={}
    languages={}
    data=list(imagelist.strip().split(';'))
    data=[d for d in data if d.find('.')!=-1]
    return random.choice(data)

# %% [markdown]
# Below the selection process:
# * If the article has a Wikidata image (not a flag, as this is likely a duplicate), select it as the article's image
# * Otherwise, if the article has an associated Commons category, call the `select_image_category` function
# * Otherwise, choose an image among the ones from related Wikipedia articles  in other languages, using the `select_image_language` function

# %%
stats={}
####
for wiki in languages:
    selected=[] #stores selected images for each article
    notes=[] #stores information about the source where the candidate image was drawn from
    wikis=[]
    data_small=allimages[wiki].sample(len(allimages[wiki]))
    language=wiki.replace('wiki','')
    #rtl=direction[wiki] #right to left -> rtl; left to right -> ltr
    for wikidata,commons,wikipedia in zip(data_small['hasimage'],data_small['category_imagelist'],data_small['lan_images']):
        image=None
        note=None
        if str(wikidata)=='None' or wikidata.lower().find('flag') !=-1:
            if str(commons)!='None':
                image=select_image_category(commons)
                note='image was found in the Commons category linked in the Wikidata item'
        else:
            image=wikidata
            note='image was in the Wikidata item'
        if str(wikipedia)!='None':
                imagew,lans,goodimages=select_image_language(wikipedia)
                if len(goodimages)==0:
                    goodimages=None
                wikis.append(goodimages)
                if image is None and imagew is not None:
                        image=imagew
                        note='image was found in the same article for the following wikis: '+','.join(lans)
        else:
            wikis.append(None)
        selected.append(image)
        notes.append(note)
#         if image is not None:
#             properties.append(get_properties(image,language,rtl,page))
#         else:
#             properties.append([None,None,None,None,None,None,None,None,None])
    #updating table
    data_small['selected']=selected
    data_small['notes']=notes
    data_small['good_interlinks']=wikis
    hasimage=data_small[data_small['hasimage'].astype(str).ne('None')]
    hasrec=data_small[data_small['selected'].astype(str).ne('None')]
    commonscategory=data_small[data_small['category_imagelist'].astype(str).ne('None')]
    lanimages=data_small[data_small['good_interlinks'].astype(str).ne('None')]
    all3images=data_small[(data_small['hasimage'].astype(str).ne('None')) & (data_small['commonscategory'].astype(str).ne('None')) & (data_small['good_interlinks'].astype(str).ne('None'))]
    data_small[data_small['selected'].astype(str).ne('None')][['page_title','selected','notes']].to_csv('Output/'+wiki+'_wd_images.tsv',sep='\t')
    print("total number of articles: "+str(total[wiki]))
    print("number of unillustrated articles: "+str(len(qids_and_properties[wiki])))
    print("number of articles with at least 1 recommendation: "+str(len(hasrec)))
    print("number of articles items with Wikidata image: "+str(len(hasimage)))
    print("number of articles items with Wikidata Commons Category: "+str(len(commonscategory)))
    print("number of articles items with Language Links: "+str(len(lanimages)))
    print("number of articles items with 3 sources: "+str(len(all3images)))
    stats[wiki]=[total[wiki],len(qids_and_properties[wiki]),len(hasrec),len(all3images),len(hasimage),len(commonscategory),len(lanimages)]
# Out:
# total number of articles: 6199587
# number of unillustrated articles: 2932613
# number of articles with at least 1 recommendation: 164481
# number of articles items with Wikidata image: 36630
# number of articles items with Wikidata Commons Category: 55628
# number of articles items with Language Links: 131317
# number of articles items with 3 sources: 13195
# total number of articles: 1080564
# number of unillustrated articles: 581710
# number of articles with at least 1 recommendation: 62670
# number of articles items with Wikidata image: 7075
# number of articles items with Wikidata Commons Category: 22343
# number of articles items with Language Links: 56767
# number of articles items with 3 sources: 4159
# total number of articles: 526990
# number of unillustrated articles: 274338
# number of articles with at least 1 recommendation: 52793
# number of articles items with Wikidata image: 16106
# number of articles items with Wikidata Commons Category: 23922
# number of articles items with Language Links: 48945
# number of articles items with 3 sources: 10426
# total number of articles: 467573
# number of unillustrated articles: 182177
# number of articles with at least 1 recommendation: 41081
# number of articles items with Wikidata image: 8359
# number of articles items with Wikidata Commons Category: 16394
# number of articles items with Language Links: 37316
# number of articles items with 3 sources: 4411
# total number of articles: 1259538
# number of unillustrated articles: 867672
# number of articles with at least 1 recommendation: 86872
# number of articles items with Wikidata image: 49246
# number of articles items with Wikidata Commons Category: 47527
# number of articles items with Language Links: 82303
# number of articles items with 3 sources: 38743
# total number of articles: 2273610
# number of unillustrated articles: 952994
# number of articles with at least 1 recommendation: 100777
# number of articles items with Wikidata image: 10975
# number of articles items with Wikidata Commons Category: 29480
# number of articles items with Language Links: 88123
# number of articles items with 3 sources: 4058
# total number of articles: 755709
# number of unillustrated articles: 304253
# number of articles with at least 1 recommendation: 59607
# number of articles items with Wikidata image: 23729
# number of articles items with Wikidata Commons Category: 25880
# number of articles items with Language Links: 55970
# number of articles items with 3 sources: 14738
# total number of articles: 1048255
# number of unillustrated articles: 388605
# number of articles with at least 1 recommendation: 82326
# number of articles items with Wikidata image: 29809
# number of articles items with Wikidata Commons Category: 33476
# number of articles items with Language Links: 76298
# number of articles items with 3 sources: 17239
# total number of articles: 1680385
# number of unillustrated articles: 584290
# number of articles with at least 1 recommendation: 65652
# number of articles items with Wikidata image: 5465
# number of articles items with Wikidata Commons Category: 19191
# number of articles items with Language Links: 59431
# number of articles items with 3 sources: 2501
# total number of articles: 382825
# number of unillustrated articles: 151620
# number of articles with at least 1 recommendation: 38719
# number of articles items with Wikidata image: 12446
# number of articles items with Wikidata Commons Category: 17020
# number of articles items with Language Links: 36742
# number of articles items with 3 sources: 8174
# total number of articles: 1441429
# number of unillustrated articles: 560334
# number of articles with at least 1 recommendation: 76550
# number of articles items with Wikidata image: 13918
# number of articles items with Wikidata Commons Category: 25283
# number of articles items with Language Links: 71317
# number of articles items with 3 sources: 7729
# total number of articles: 282232
# number of unillustrated articles: 73261
# number of articles with at least 1 recommendation: 17124
# number of articles items with Wikidata image: 2377
# number of articles items with Wikidata Commons Category: 6752
# number of articles items with Language Links: 16072
# number of articles items with 3 sources: 1175
# total number of articles: 3514965
# number of unillustrated articles: 1686664
# number of articles with at least 1 recommendation: 93437
# number of articles items with Wikidata image: 28791
# number of articles items with Wikidata Commons Category: 39101
# number of articles items with Language Links: 81309
# number of articles items with 3 sources: 15454
# total number of articles: 1058563
# number of unillustrated articles: 365209
# number of articles with at least 1 recommendation: 55375
# number of articles items with Wikidata image: 11669
# number of articles items with Wikidata Commons Category: 18441
# number of articles items with Language Links: 51696
# number of articles items with 3 sources: 6386
# total number of articles: 479215
# number of unillustrated articles: 170936
# number of articles with at least 1 recommendation: 30226
# number of articles items with Wikidata image: 3918
# number of articles items with Wikidata Commons Category: 12441
# number of articles items with Language Links: 27618
# number of articles items with 3 sources: 2449
# total number of articles: 278487
# number of unillustrated articles: 96729
# number of articles with at least 1 recommendation: 16072
# number of articles items with Wikidata image: 2311
# number of articles items with Wikidata Commons Category: 6710
# number of articles items with Language Links: 15327
# number of articles items with 3 sources: 1750
# total number of articles: 640678
# number of unillustrated articles: 126102
# number of articles with at least 1 recommendation: 30526
# number of articles items with Wikidata image: 9852
# number of articles items with Wikidata Commons Category: 11113
# number of articles items with Language Links: 29520
# number of articles items with 3 sources: 5393
# total number of articles: 364458
# number of unillustrated articles: 105412
# number of articles with at least 1 recommendation: 23972
# number of articles items with Wikidata image: 2207
# number of articles items with Wikidata Commons Category: 8930
# number of articles items with Language Links: 22216
# number of articles items with 3 sources: 1616
# total number of articles: 1171440
# number of unillustrated articles: 759418
# number of articles with at least 1 recommendation: 33462
# number of articles items with Wikidata image: 1078
# number of articles items with Wikidata Commons Category: 12198
# number of articles items with Language Links: 28456
# number of articles items with 3 sources: 695
# total number of articles: 5377763
# number of unillustrated articles: 1357405
# number of articles with at least 1 recommendation: 65737
# number of articles items with Wikidata image: 34900
# number of articles items with Wikidata Commons Category: 47452
# number of articles items with Language Links: 60310
# number of articles items with 3 sources: 34514
# total number of articles: 2506229
# number of unillustrated articles: 1190517
# number of articles with at least 1 recommendation: 118267
# number of articles items with Wikidata image: 38367
# number of articles items with Wikidata Commons Category: 40179
# number of articles items with Language Links: 105161
# number of articles items with 3 sources: 17146
# total number of articles: 99172
# number of unillustrated articles: 33642
# number of articles with at least 1 recommendation: 9139
# number of articles items with Wikidata image: 2325
# number of articles items with Wikidata Commons Category: 4795
# number of articles items with Language Links: 8670
# number of articles items with 3 sources: 1527

# %%
stats_refined={}
####
for wiki in languages:
    selected=[] #stores selected images for each article
    notes=[] #stores information about the source where the candidate image was drawn from
    wikis=[]
    data_small=allimages[wiki].sample(len(allimages[wiki]))
    language=wiki.replace('wiki','')
    #rtl=direction[wiki] #right to left -> rtl; left to right -> ltr
    for wikidata,commons,wikipedia,jdata in zip(data_small['hasimage'],data_small['category_imagelist'],data_small['lan_images'],data_small['instanceof']):
        if jdata is not None:
            qid=json.loads(jdata)["numeric-id"]
            if qid in [4167410,577,13406463]:
                selected.append(None)
                notes.append(None)
                wikis.append(None)
                continue
        image=None
        note=None
        if str(wikidata)=='None' or wikidata.lower().find('flag') !=-1:
            if str(commons)!='None':
                image=select_image_category(commons)
                note='image was found in the Commons category linked in the Wikidata item'
        else:
            image=wikidata
            note='image was in the Wikidata item'
        if str(wikipedia)!='None':
                imagew,lans,goodimages=select_image_language(wikipedia)
                if len(goodimages)==0:
                    goodimages=None
                wikis.append(goodimages)
                if image is None and imagew is not None:
                        image=imagew
                        note='image was found in the same article for the following wikis: '+','.join(lans)
        else:
            wikis.append(None)
        selected.append(image)
        notes.append(note)
#         if image is not None:
#             properties.append(get_properties(image,language,rtl,page))
#         else:
#             properties.append([None,None,None,None,None,None,None,None,None])
    #updating table
    data_small['selected']=selected
    data_small['notes']=notes
    data_small['good_interlinks']=wikis
    hasimage=data_small[data_small['hasimage'].astype(str).ne('None')]
    hasrec=data_small[data_small['selected'].astype(str).ne('None')]
    commonscategory=data_small[data_small['category_imagelist'].astype(str).ne('None')]
    lanimages=data_small[data_small['good_interlinks'].astype(str).ne('None')]
    all3images=data_small[(data_small['hasimage'].astype(str).ne('None')) & (data_small['commonscategory'].astype(str).ne('None')) & (data_small['good_interlinks'].astype(str).ne('None'))]
    data_small[data_small['selected'].astype(str).ne('None')][['page_title','selected','notes']].to_csv('Output/'+wiki+'_wd_images.tsv',sep='\t')
    print("total number of articles: "+str(total[wiki]))
    print("number of unillustrated articles: "+str(len(qids_and_properties[wiki])))
    print("number of articles with at least 1 recommendation: "+str(len(hasrec)))
    print("number of articles items with Wikidata image: "+str(len(hasimage)))
    print("number of articles items with Wikidata Commons Category: "+str(len(commonscategory)))
    print("number of articles items with Language Links: "+str(len(lanimages)))
    print("number of articles items with 3 sources: "+str(len(all3images)))
    stats_refined[wiki]=[total[wiki],len(qids_and_properties[wiki]),len(hasrec),len(all3images),len(hasimage),len(commonscategory),len(lanimages)]
# Out:
# total number of articles: 6199587
# number of unillustrated articles: 2932613
# number of articles with at least 1 recommendation: 154508
# number of articles items with Wikidata image: 36630
# number of articles items with Wikidata Commons Category: 55628
# number of articles items with Language Links: 123706
# number of articles items with 3 sources: 13183
# total number of articles: 1080564
# number of unillustrated articles: 581710
# number of articles with at least 1 recommendation: 59551
# number of articles items with Wikidata image: 7075
# number of articles items with Wikidata Commons Category: 22343
# number of articles items with Language Links: 53792
# number of articles items with 3 sources: 4140
# total number of articles: 526990
# number of unillustrated articles: 274338
# number of articles with at least 1 recommendation: 48417
# number of articles items with Wikidata image: 16106
# number of articles items with Wikidata Commons Category: 23922
# number of articles items with Language Links: 44868
# number of articles items with 3 sources: 10407
# total number of articles: 467573
# number of unillustrated articles: 182177
# number of articles with at least 1 recommendation: 37300
# number of articles items with Wikidata image: 8359
# number of articles items with Wikidata Commons Category: 16394
# number of articles items with Language Links: 33803
# number of articles items with 3 sources: 4400
# total number of articles: 1259538
# number of unillustrated articles: 867672
# number of articles with at least 1 recommendation: 83785
# number of articles items with Wikidata image: 49246
# number of articles items with Wikidata Commons Category: 47527
# number of articles items with Language Links: 79330
# number of articles items with 3 sources: 38725
# total number of articles: 2273610
# number of unillustrated articles: 952994
# number of articles with at least 1 recommendation: 94594
# number of articles items with Wikidata image: 10975
# number of articles items with Wikidata Commons Category: 29480
# number of articles items with Language Links: 82894
# number of articles items with 3 sources: 4050
# total number of articles: 755709
# number of unillustrated articles: 304253
# number of articles with at least 1 recommendation: 55382
# number of articles items with Wikidata image: 23729
# number of articles items with Wikidata Commons Category: 25880
# number of articles items with Language Links: 51916
# number of articles items with 3 sources: 14718
# total number of articles: 1048255
# number of unillustrated articles: 388605
# number of articles with at least 1 recommendation: 79483
# number of articles items with Wikidata image: 29809
# number of articles items with Wikidata Commons Category: 33476
# number of articles items with Language Links: 73738
# number of articles items with 3 sources: 17233
# total number of articles: 1680385
# number of unillustrated articles: 584290
# number of articles with at least 1 recommendation: 60415
# number of articles items with Wikidata image: 5465
# number of articles items with Wikidata Commons Category: 19191
# number of articles items with Language Links: 54878
# number of articles items with 3 sources: 2489
# total number of articles: 382825
# number of unillustrated articles: 151620
# number of articles with at least 1 recommendation: 35561
# number of articles items with Wikidata image: 12446
# number of articles items with Wikidata Commons Category: 17020
# number of articles items with Language Links: 33721
# number of articles items with 3 sources: 8157
# total number of articles: 1441429
# number of unillustrated articles: 560334
# number of articles with at least 1 recommendation: 71456
# number of articles items with Wikidata image: 13918
# number of articles items with Wikidata Commons Category: 25283
# number of articles items with Language Links: 66612
# number of articles items with 3 sources: 7710
# total number of articles: 282232
# number of unillustrated articles: 73261
# number of articles with at least 1 recommendation: 14453
# number of articles items with Wikidata image: 2377
# number of articles items with Wikidata Commons Category: 6752
# number of articles items with Language Links: 13503
# number of articles items with 3 sources: 1169
# total number of articles: 3514965
# number of unillustrated articles: 1686664
# number of articles with at least 1 recommendation: 91337
# number of articles items with Wikidata image: 28791
# number of articles items with Wikidata Commons Category: 39101
# number of articles items with Language Links: 79467
# number of articles items with 3 sources: 15449
# total number of articles: 1058563
# number of unillustrated articles: 365209
# number of articles with at least 1 recommendation: 51154
# number of articles items with Wikidata image: 11669
# number of articles items with Wikidata Commons Category: 18441
# number of articles items with Language Links: 47804
# number of articles items with 3 sources: 6366
# total number of articles: 479215
# number of unillustrated articles: 170936
# number of articles with at least 1 recommendation: 26559
# number of articles items with Wikidata image: 3918
# number of articles items with Wikidata Commons Category: 12441
# number of articles items with Language Links: 24159
# number of articles items with 3 sources: 2441
# total number of articles: 278487
# number of unillustrated articles: 96729
# number of articles with at least 1 recommendation: 13531
# number of articles items with Wikidata image: 2311
# number of articles items with Wikidata Commons Category: 6710
# number of articles items with Language Links: 12913
# number of articles items with 3 sources: 1734
# total number of articles: 640678
# number of unillustrated articles: 126102
# number of articles with at least 1 recommendation: 27326
# number of articles items with Wikidata image: 9852
# number of articles items with Wikidata Commons Category: 11113
# number of articles items with Language Links: 26477
# number of articles items with 3 sources: 5377
# total number of articles: 364458
# number of unillustrated articles: 105412
# number of articles with at least 1 recommendation: 21481
# number of articles items with Wikidata image: 2207
# number of articles items with Wikidata Commons Category: 8930
# number of articles items with Language Links: 19778
# number of articles items with 3 sources: 1601
# total number of articles: 1171440
# number of unillustrated articles: 759418
# number of articles with at least 1 recommendation: 32956
# number of articles items with Wikidata image: 1078
# number of articles items with Wikidata Commons Category: 12198
# number of articles items with Language Links: 27951
# number of articles items with 3 sources: 684
# total number of articles: 5377763
# number of unillustrated articles: 1357405
# number of articles with at least 1 recommendation: 61839
# number of articles items with Wikidata image: 34900
# number of articles items with Wikidata Commons Category: 47452
# number of articles items with Language Links: 56644
# number of articles items with 3 sources: 34497
# total number of articles: 2506229
# number of unillustrated articles: 1190517
# number of articles with at least 1 recommendation: 110771
# number of articles items with Wikidata image: 38367
# number of articles items with Wikidata Commons Category: 40179
# number of articles items with Language Links: 99310
# number of articles items with 3 sources: 17133
# total number of articles: 99172
# number of unillustrated articles: 33642
# number of articles with at least 1 recommendation: 6921
# number of articles items with Wikidata image: 2325
# number of articles items with Wikidata Commons Category: 4795
# number of articles items with Language Links: 6478
# number of articles items with 3 sources: 1511

# %%
stats_refined
# Out:
# {'enwiki': [6199587, 2932613, 154508, 13183, 36630, 55628, 123706],
#  'arwiki': [1080564, 581710, 59551, 4140, 7075, 22343, 53792],
#  'kowiki': [526990, 274338, 48417, 10407, 16106, 23922, 44868],
#  'cswiki': [467573, 182177, 37300, 4400, 8359, 16394, 33803],
#  'viwiki': [1259538, 867672, 83785, 38725, 49246, 47527, 79330],
#  'frwiki': [2273610, 952994, 94594, 4050, 10975, 29480, 82894],
#  'fawiki': [755709, 304253, 55382, 14718, 23729, 25880, 51916],
#  'ptwiki': [1048255, 388605, 79483, 17233, 29809, 33476, 73738],
#  'ruwiki': [1680385, 584290, 60415, 2489, 5465, 19191, 54878],
#  'trwiki': [382825, 151620, 35561, 8157, 12446, 17020, 33721],
#  'plwiki': [1441429, 560334, 71456, 7710, 13918, 25283, 66612],
#  'hewiki': [282232, 73261, 14453, 1169, 2377, 6752, 13503],
#  'svwiki': [3514965, 1686664, 91337, 15449, 28791, 39101, 79467],
#  'ukwiki': [1058563, 365209, 51154, 6366, 11669, 18441, 47804],
#  'huwiki': [479215, 170936, 26559, 2441, 3918, 12441, 24159],
#  'hywiki': [278487, 96729, 13531, 1734, 2311, 6710, 12913],
#  'srwiki': [640678, 126102, 27326, 5377, 9852, 11113, 26477],
#  'euwiki': [364458, 105412, 21481, 1601, 2207, 8930, 19778],
#  'arzwiki': [1171440, 759418, 32956, 684, 1078, 12198, 27951],
#  'cebwiki': [5377763, 1357405, 61839, 34497, 34900, 47452, 56644],
#  'dewiki': [2506229, 1190517, 110771, 17133, 38367, 40179, 99310],
#  'bnwiki': [99172, 33642, 6921, 1511, 2325, 4795, 6478]}
